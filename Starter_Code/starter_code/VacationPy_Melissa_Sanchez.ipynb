# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import matplotlib as plt
# Import API key
from api_keys import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head(15)
# Out:
#     City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         0          faya  18.3851   42.4509     22.06        35          21
# 1         1       farsund  58.0948    6.8047     13.30       100           0
# 2         2   new norfolk -42.7826  147.0587     11.72        58          12
# 3         3     jamestown  42.0970  -79.2353      5.77        77         100
# 4         4       lanzhou  36.0564  103.7922     14.53        48          59
# 5         5       ushuaia -54.8000  -68.3000      8.81        81          75
# 6         6        albany  42.6001  -73.9662     10.36        74          29
# 7         7     carnarvon -24.8667  113.6333     20.02        76           0
# 8         8      sisimiut  66.9395  -53.6735      2.72        98         100
# 9         9  saint-pierre -21.3393   55.4781     22.82        68           0
# 10       10      colorado -22.8375  -51.9731     20.36        86          96
# 11       11    nikolskoye  59.7035   30.7861      8.94        90         100
# 12       12        trairi  -3.2778  -39.2689     31.07        51          34
# 13       13     dobryanka  58.4619   56.4165      5.63        93         100
# 14       14       qaanaaq  77.4840  -69.3632    -17.32        74          86
#
#     Wind Speed Country        Date
# 0         2.60      SA  1666108228
# 1         7.65      NO  1666108228
# 2         1.34      AU  1666108230
# 3         9.77      US  1666107934
# 4         1.20      CN  1666108230
# 5         3.09      AR  1666108231
# 6         2.10      US  1666108231
# 7         7.46      AU  1666108232
# 8         3.79      GL  1666108235
# 9         5.14      RE  1666108236
# 10        4.69      BR  1666107965
# 11        3.22      RU  1666108237
# 12        8.09      BR  1666108038
# 13        3.55      RU  1666108237
# 14        3.36      GL  1666108238

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\melis\.conda\envs\edx\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\melis\.conda\envs\edx\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\melis\.conda\envs\edx\lib\site-packages (0.14.0)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\melis\.conda\envs\edx\lib\site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in c:\users\melis\appdata\roaming\python\python310\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\melis\.conda\envs\edx\lib\site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\melis\.conda\envs\edx\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\melis\.conda\envs\edx\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\melis\.conda\envs\edx\lib\site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\melis\.conda\envs\edx\lib\site-packages (from fiona>=1.8.21->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in c:\users\melis\.conda\envs\edx\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\melis\.conda\envs\edx\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\melis\.conda\envs\edx\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\melis\appdata\roaming\python\python310\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\melis\appdata\roaming\python\python310\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\melis\.conda\envs\edx\lib\site-packages (from pandas>=1.4.0->geopandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\melis\.conda\envs\edx\lib\site-packages (from pandas>=1.4.0->geopandas) (1.24.3)
# Requirement already satisfied: colorama in c:\users\melis\appdata\roaming\python\python310\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c pyviz geoviews
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\melis\.conda\envs\EdX
#
#   added / updated specs:
#     - geoviews
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.08.22 |       haa95532_0         123 KB
#     cartopy-0.21.1             |  py310hb6e7958_0         1.6 MB
#     certifi-2023.7.22          |  py310haa95532_0         154 KB
#     cftime-1.6.2               |  py310h9128911_0         175 KB
#     geopandas-base-0.9.0       |             py_1         919 KB
#     geos-3.8.0                 |       h33f27b4_0         905 KB
#     geoviews-1.9.6             |             py_0           4 KB  pyviz
#     geoviews-core-1.9.6        |             py_0         403 KB  pyviz
#     hdf4-4.2.13                |       h712560f_2         1.3 MB
#     jupyter_client-7.4.9       |  py310haa95532_0         226 KB
#     jupyter_server-1.23.4      |  py310haa95532_0         402 KB
#     libnetcdf-4.8.1            |       h6685c40_2         668 KB
#     libzip-1.8.0               |       h49b8836_0          95 KB
#     netcdf4-1.6.2              |  py310hadf358c_0         349 KB
#     openssl-1.1.1w             |       h2bbff1b_0         5.5 MB
#     proj-8.2.1                 |       h5ed7ab8_0         2.4 MB
#     pyproj-3.4.1               |  py310h95ea4f9_0         391 KB
#     pyshp-2.1.3                |     pyhd3eb1b0_0          37 KB
#     pyzmq-23.2.0               |  py310hd77b12b_0         405 KB
#     shapely-2.0.1              |  py310h6c53999_0         396 KB
#     ------------------------------------------------------------
#                                            Total:        16.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   cartopy            pkgs/main/win-64::cartopy-0.21.1-py310hb6e7958_0
#   cftime             pkgs/main/win-64::cftime-1.6.2-py310h9128911_0
#   geopandas-base     pkgs/main/noarch::geopandas-base-0.9.0-py_1
#   geos               pkgs/main/win-64::geos-3.8.0-h33f27b4_0
#   geoviews           pyviz/noarch::geoviews-1.9.6-py_0
#   geoviews-core      pyviz/noarch::geoviews-core-1.9.6-py_0
#   hdf4               pkgs/main/win-64::hdf4-4.2.13-h712560f_2
#   libnetcdf          pkgs/main/win-64::libnetcdf-4.8.1-h6685c40_2
#   libzip             pkgs/main/win-64::libzip-1.8.0-h49b8836_0
#   netcdf4            pkgs/main/win-64::netcdf4-1.6.2-py310hadf358c_0
#   proj               pkgs/main/win-64::proj-8.2.1-h5ed7ab8_0
#   pyproj             pkgs/main/win-64::pyproj-3.4.1-py310h95ea4f9_0
#   pyshp              pkgs/main/noarch::pyshp-2.1.3-pyhd3eb1b0_0
#   shapely            pkgs/main/win-64::shapely-2.0.1-py310h6c53999_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2023.01.10-~ --> pkgs/main::ca-certificates-2023.08.22-haa95532_0
#   certifi            anaconda::certifi-2022.12.7-py310haa9~ --> pkgs/main::certifi-2023.7.22-py310haa95532_0
#   openssl                                 1.1.1u-h2bbff1b_0 --> 1.1.1w-h2bbff1b_0
#
# The following packages will be DOWNGRADED:
#
#   jupyter_client                      8.1.0-py310haa95532_0 --> 7.4.9-py310haa95532_0
#   jupyter_server                      2.5.0-py310haa95532_0 --> 1.23.4-py310haa95532_0
#   pyzmq                              25.1.0-py310hd77b12b_0 --> 23.2.0-py310hd77b12b_0
#
#
#
# Downloading and Extracting Packages
#
# ca-certificates-2023 | 123 KB    |            |   0%
#
# libzip-1.8.0         | 95 KB     |            |   0%
#
#
# openssl-1.1.1w       | 5.5 MB    |            |   0%
#
#
#
# geos-3.8.0           | 905 KB    |            |   0%
#
#
#
#
# libnetcdf-4.8.1      | 668 KB    |            |   0%
#
#
#
#
#
# netcdf4-1.6.2        | 349 KB    |            |   0%
#
#
#
#
#
#
# jupyter_server-1.23. | 402 KB    |            |   0%
#
#
#
#
#
#
#
# jupyter_client-7.4.9 | 226 KB    |            |   0%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# pyproj-3.4.1         | 391 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# geoviews-core-1.9.6  | 403 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# pyzmq-23.2.0         | 405 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# geoviews-1.9.6       | 4 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cartopy-0.21.1       | 1.6 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.9.0 | 919 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyshp-2.1.3          | 37 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cftime-1.6.2         | 175 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.1        | 396 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# openssl-1.1.1w       | 5.5 MB    |            |   0%
# ca-certificates-2023 | 123 KB    | #2         |  13%
# ca-certificates-2023 | 123 KB    | ########## | 100%
#
#
#
# geos-3.8.0           | 905 KB    | 1          |   2%
#
#
# openssl-1.1.1w       | 5.5 MB    | 8          |   9%
#
#
#
#
# libnetcdf-4.8.1      | 668 KB    | 2          |   2%
#
#
# openssl-1.1.1w       | 5.5 MB    | #6         |  17%
#
#
#
# geos-3.8.0           | 905 KB    | #4         |  14%
#
#
#
#
# libnetcdf-4.8.1      | 668 KB    | #9         |  19%
#
#
#
#
#
# netcdf4-1.6.2        | 349 KB    | 4          |   5%
#
#
# openssl-1.1.1w       | 5.5 MB    | ##3        |  23%
#
#
#
# geos-3.8.0           | 905 KB    | ##4        |  25%
#
#
#
#
# libnetcdf-4.8.1      | 668 KB    | ###8       |  38%
#
#
# openssl-1.1.1w       | 5.5 MB    | ##9        |  30%
#
#
#
#
#
# netcdf4-1.6.2        | 349 KB    | ###6       |  37%
#
#
#
# geos-3.8.0           | 905 KB    | #####3     |  53%
#
#
#
#
#
# netcdf4-1.6.2        | 349 KB    | ########## | 100%
#
#
#
#
# libnetcdf-4.8.1      | 668 KB    | #######6   |  77%
#
#
# openssl-1.1.1w       | 5.5 MB    | ###6       |  36%
#
# libzip-1.8.0         | 95 KB     | #6         |  17%
#
#
#
# geos-3.8.0           | 905 KB    | #########  |  90%
#
#
#
#
# libnetcdf-4.8.1      | 668 KB    | ########## | 100%
#
#
#
#
# libnetcdf-4.8.1      | 668 KB    | ########## | 100%
#
#
#
#
#
#
# jupyter_server-1.23. | 402 KB    | 3          |   4%
#
#
# openssl-1.1.1w       | 5.5 MB    | ####3      |  43%
#
# libzip-1.8.0         | 95 KB     | ########## | 100%
#
# libzip-1.8.0         | 95 KB     | ########## | 100%
#
#
#
#
#
#
#
# jupyter_client-7.4.9 | 226 KB    | 7          |   7%
#
#
# openssl-1.1.1w       | 5.5 MB    | ####9      |  49%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    |            |   1%
#
#
#
#
#
#
#
#
#
# pyproj-3.4.1         | 391 KB    | 4          |   4%
#
#
#
#
#
#
# jupyter_server-1.23. | 402 KB    | ########## | 100%
#
#
#
#
#
#
# jupyter_server-1.23. | 402 KB    | ########## | 100%
#
#
#
# geos-3.8.0           | 905 KB    | ########## | 100%
#
#
# openssl-1.1.1w       | 5.5 MB    | #####5     |  55%
#
#
#
#
#
#
#
#
#
# pyproj-3.4.1         | 391 KB    | 8          |   8%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    | 5          |   5%
#
#
# openssl-1.1.1w       | 5.5 MB    | ######4    |  65%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    | ##3        |  24%
#
#
#
#
#
#
#
#
#
# pyproj-3.4.1         | 391 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# pyproj-3.4.1         | 391 KB    | ########## | 100%
#
#
# openssl-1.1.1w       | 5.5 MB    | #######1   |  72%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
# pyzmq-23.2.0         | 405 KB    | 3          |   4%
#
#
# openssl-1.1.1w       | 5.5 MB    | #######8   |  78%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
# pyzmq-23.2.0         | 405 KB    | #####1     |  51%
#
#
#
#
#
#
#
# jupyter_client-7.4.9 | 226 KB    | #######7   |  78%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    | #####5     |  56%
#
#
#
#
#
#
#
#
#
#
#
# pyzmq-23.2.0         | 405 KB    | #########4 |  95%
#
#
# openssl-1.1.1w       | 5.5 MB    | ########4  |  85%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    | ######8    |  68%
#
#
#
#
#
#
#
# jupyter_client-7.4.9 | 226 KB    | #########1 |  92%
#
#
# openssl-1.1.1w       | 5.5 MB    | #########  |  90%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    | ########   |  81%
#
#
# openssl-1.1.1w       | 5.5 MB    | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pyzmq-23.2.0         | 405 KB    | ########## | 100%
#
#
#
#
#
#
#
# jupyter_client-7.4.9 | 226 KB    | ########## | 100%
#
#
#
#
#
#
#
# jupyter_client-7.4.9 | 226 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cartopy-0.21.1       | 1.6 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.9.0 | 919 KB    | 1          |   2%
#
#
#
#
#
#
#
#
# proj-8.2.1           | 2.4 MB    | ########## | 100%
#
#
# openssl-1.1.1w       | 5.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyshp-2.1.3          | 37 KB     | ####3      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyshp-2.1.3          | 37 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.9.0 | 919 KB    | ####5      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.9.0 | 919 KB    | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ###9       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cftime-1.6.2         | 175 KB    | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #####3     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cftime-1.6.2         | 175 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cftime-1.6.2         | 175 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.1        | 396 KB    | 4          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.9.0 | 919 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ######7    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
# geoviews-1.9.6       | 4 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# geoviews-core-1.9.6  | 403 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# geoviews-1.9.6       | 4 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# geoviews-core-1.9.6  | 403 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.3 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #######9   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.3 MB    | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.1        | 396 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.1        | 396 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.3 MB    | #####      |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.3 MB    | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.9.0

# %%
# %%capture --no-display


# Configure the map plot
import geopandas as gpd
import geoviews as gv
import geoviews.feature as gf
import xarray as xr
from cartopy import crs

gv.extension('bokeh', 'matplotlib')

# Display the map

import holoviews as hv
from holoviews import opts
hv.extension('bokeh')
tile=hv.Tiles('https://tile.openstreetmap.org/{Z}/{X}/{Y}.png', name="OSM").opts(width=800, height=600)
city_data_df.hvplot.points('Lng', 'Lat', geo=True, alpha=0.4, size = "Humidity",
                       xlim=(-180, 180), ylim=(-70, 85), tiles=tile,legend='right',color = "City",)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

ideal_cities_df=city_data_df.loc[(city_data_df['Max Temp']<28) & (city_data_df['Humidity']<70)]
ideal_cities_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          0          faya  18.3851   42.4509     22.06        35          21
# 2          2   new norfolk -42.7826  147.0587     11.72        58          12
# 4          4       lanzhou  36.0564  103.7922     14.53        48          59
# 9          9  saint-pierre -21.3393   55.4781     22.82        68           0
# 23        23       rikitea -23.1203 -134.9692     20.41        65          77
# ..       ...           ...      ...       ...       ...       ...         ...
# 560      560       changli  39.7042  119.1506      9.17        33           0
# 561      561         choma -16.8065   26.9531     26.75        22          94
# 562      562          tena  -0.9833  -77.8167     25.09        62         100
# 565      565       wyndham  37.6985  -77.6125     12.81        52           3
# 575      575       iquique -20.2208  -70.1431     17.02        68           6
#
#      Wind Speed Country        Date
# 0          2.60      SA  1666108228
# 2          1.34      AU  1666108230
# 4          1.20      CN  1666108230
# 9          5.14      RE  1666108236
# 23         9.23      PF  1666108244
# ..          ...     ...         ...
# 560        2.41      CN  1666108557
# 561        3.63      ZM  1666108557
# 562        1.58      EC  1666108557
# 565        1.79      US  1666108480
# 575        3.50      CL  1666108566
#
# [166 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df=ideal_cities_df.iloc[: , [1,8,2,3,5]].copy()
hotel_df['Hotel Name']=""
hotel_df.head()
# Display sample data
hotel_df.head()
# Out:
#             City Country      Lat       Lng  Humidity Hotel Name
# 0           faya      SA  18.3851   42.4509        35
# 2    new norfolk      AU -42.7826  147.0587        58
# 4        lanzhou      CN  36.0564  103.7922        48
# 9   saint-pierre      RE -21.3393   55.4781        68
# 23       rikitea      PF -23.1203 -134.9692        65

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
     "Categories":"Accommodation.Hotel",
    "Limit": 1,
    "ApiKey": geoapify_key
   
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat=hotel_df.loc[index, "Lat"]
    lng=hotel_df.loc[index, "Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    params["text"]=hotel_df.loc[index, "City"]
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    # Convert the API response to JSON format
    name_address =  name_address = requests.get(base_url, params=params).json()
         
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# faya - nearest hotel: No hotel found
# new norfolk - nearest hotel: No hotel found
# lanzhou - nearest hotel: No hotel found
# saint-pierre - nearest hotel: No hotel found
# rikitea - nearest hotel: No hotel found
# constitucion - nearest hotel: No hotel found
# bambous virieux - nearest hotel: No hotel found
# zangakatun - nearest hotel: No hotel found
# midwest city - nearest hotel: No hotel found
# naberera - nearest hotel: No hotel found
# drochia - nearest hotel: No hotel found
# klaksvik - nearest hotel: No hotel found
# collierville - nearest hotel: No hotel found
# hobart - nearest hotel: No hotel found
# lasa - nearest hotel: No hotel found
# banda - nearest hotel: No hotel found
# atuona - nearest hotel: No hotel found
# caravelas - nearest hotel: No hotel found
# nalut - nearest hotel: No hotel found
# mahebourg - nearest hotel: No hotel found
# rafaela - nearest hotel: No hotel found
# ponta do sol - nearest hotel: No hotel found
# solnechnyy - nearest hotel: No hotel found
# saint george - nearest hotel: No hotel found
# alba - nearest hotel: No hotel found
# arman - nearest hotel: No hotel found
# zhangye - nearest hotel: No hotel found
# shenjiamen - nearest hotel: No hotel found
# heihe - nearest hotel: No hotel found
# rio gallegos - nearest hotel: No hotel found
# palencia - nearest hotel: No hotel found
# inhambane - nearest hotel: No hotel found
# yidu - nearest hotel: No hotel found
# cedar city - nearest hotel: No hotel found
# hithadhoo - nearest hotel: No hotel found
# kulykivka - nearest hotel: No hotel found
# el alto - nearest hotel: No hotel found
# punta arenas - nearest hotel: No hotel found
# baruun-urt - nearest hotel: No hotel found
# brenham - nearest hotel: No hotel found
# havelock - nearest hotel: No hotel found
# kahului - nearest hotel: No hotel found
# pangnirtung - nearest hotel: No hotel found
# almaznyy - nearest hotel: No hotel found
# belmonte - nearest hotel: No hotel found
# ambilobe - nearest hotel: No hotel found
# sur - nearest hotel: No hotel found
# la ronge - nearest hotel: No hotel found
# danielskuil - nearest hotel: No hotel found
# avera - nearest hotel: No hotel found
# challapata - nearest hotel: No hotel found
# neepawa - nearest hotel: No hotel found
# hovd - nearest hotel: No hotel found
# gwanda - nearest hotel: No hotel found
# grand gaube - nearest hotel: No hotel found
# paita - nearest hotel: No hotel found
# lagoa - nearest hotel: No hotel found
# asau - nearest hotel: No hotel found
# simao - nearest hotel: No hotel found
# bethel - nearest hotel: No hotel found
# luderitz - nearest hotel: No hotel found
# sao teotonio - nearest hotel: No hotel found
# hay river - nearest hotel: No hotel found
# san patricio - nearest hotel: No hotel found
# san cristobal - nearest hotel: No hotel found
# carrollton - nearest hotel: No hotel found
# llata - nearest hotel: No hotel found
# cap malheureux - nearest hotel: No hotel found
# rawson - nearest hotel: No hotel found
# tikaitnagar - nearest hotel: No hotel found
# aksu - nearest hotel: No hotel found
# russkaya polyana - nearest hotel: No hotel found
# broken hill - nearest hotel: No hotel found
# ordzhonikidze - nearest hotel: No hotel found
# floro - nearest hotel: No hotel found
# prieska - nearest hotel: No hotel found
# comodoro rivadavia - nearest hotel: No hotel found
# thompson - nearest hotel: No hotel found
# chengde - nearest hotel: No hotel found
# ola - nearest hotel: No hotel found
# jiuquan - nearest hotel: No hotel found
# san juan - nearest hotel: No hotel found
# monmouth - nearest hotel: No hotel found
# kamen-rybolov - nearest hotel: No hotel found
# jalu - nearest hotel: No hotel found
# valdivia - nearest hotel: No hotel found
# ulaangom - nearest hotel: No hotel found
# souillac - nearest hotel: No hotel found
# alice springs - nearest hotel: No hotel found
# kingman - nearest hotel: No hotel found
# carroll - nearest hotel: No hotel found
# tandil - nearest hotel: No hotel found
# salalah - nearest hotel: No hotel found
# harwich - nearest hotel: No hotel found
# vostok - nearest hotel: No hotel found
# viseu - nearest hotel: No hotel found
# swan river - nearest hotel: No hotel found
# rocha - nearest hotel: No hotel found
# santa rosalia - nearest hotel: No hotel found
# nerchinskiy zavod - nearest hotel: No hotel found
# torrington - nearest hotel: No hotel found
# pingliang - nearest hotel: No hotel found
# petropavlovsk-kamchatskiy - nearest hotel: No hotel found
# korla - nearest hotel: No hotel found
# katyuzhanka - nearest hotel: No hotel found
# narwar - nearest hotel: No hotel found
# sol-iletsk - nearest hotel: No hotel found
# saint anthony - nearest hotel: No hotel found
# yulara - nearest hotel: No hotel found
# roebourne - nearest hotel: No hotel found
# ribeira grande - nearest hotel: No hotel found
# saint-francois - nearest hotel: No hotel found
# usman - nearest hotel: No hotel found
# carlyle - nearest hotel: No hotel found
# woodward - nearest hotel: No hotel found
# mayo - nearest hotel: No hotel found
# kalemie - nearest hotel: No hotel found
# stolac - nearest hotel: No hotel found
# port-de-bouc - nearest hotel: No hotel found
# aktau - nearest hotel: No hotel found
# pachino - nearest hotel: No hotel found
# broome - nearest hotel: No hotel found
# lakki marwat - nearest hotel: No hotel found
# yangliuqing - nearest hotel: No hotel found
# tieling - nearest hotel: No hotel found
# havoysund - nearest hotel: No hotel found
# la paz - nearest hotel: No hotel found
# barroso - nearest hotel: No hotel found
# vryburg - nearest hotel: No hotel found
# beira - nearest hotel: No hotel found
# juegang - nearest hotel: No hotel found
# chifeng - nearest hotel: No hotel found
# salto - nearest hotel: No hotel found
# greenville - nearest hotel: No hotel found
# hirado - nearest hotel: No hotel found
# laurel - nearest hotel: No hotel found
# statesville - nearest hotel: No hotel found
# lahij - nearest hotel: No hotel found
# derzhavinsk - nearest hotel: No hotel found
# waseca - nearest hotel: No hotel found
# sfantu gheorghe - nearest hotel: No hotel found
# wadi musa - nearest hotel: No hotel found
# severo-kurilsk - nearest hotel: No hotel found
# guerrero negro - nearest hotel: No hotel found
# antofagasta - nearest hotel: No hotel found
# xuchang - nearest hotel: No hotel found
# todos santos - nearest hotel: No hotel found
# wajima - nearest hotel: No hotel found
# chivilcoy - nearest hotel: No hotel found
# mandalgovi - nearest hotel: No hotel found
# emirdag - nearest hotel: No hotel found
# tongliao - nearest hotel: No hotel found
# khudumelapye - nearest hotel: No hotel found
# talcahuano - nearest hotel: No hotel found
# gifhorn - nearest hotel: No hotel found
# juba - nearest hotel: No hotel found
# pali - nearest hotel: No hotel found
# freeport - nearest hotel: No hotel found
# bulgan - nearest hotel: No hotel found
# sorland - nearest hotel: No hotel found
# saryg-sep - nearest hotel: No hotel found
# changli - nearest hotel: No hotel found
# choma - nearest hotel: No hotel found
# tena - nearest hotel: No hotel found
# wyndham - nearest hotel: No hotel found
# iquique - nearest hotel: No hotel found
#              City Country      Lat       Lng  Humidity      Hotel Name
# 0            faya      SA  18.3851   42.4509        35  No hotel found
# 2     new norfolk      AU -42.7826  147.0587        58  No hotel found
# 4         lanzhou      CN  36.0564  103.7922        48  No hotel found
# 9    saint-pierre      RE -21.3393   55.4781        68  No hotel found
# 23        rikitea      PF -23.1203 -134.9692        65  No hotel found
# ..            ...     ...      ...       ...       ...             ...
# 560       changli      CN  39.7042  119.1506        33  No hotel found
# 561         choma      ZM -16.8065   26.9531        22  No hotel found
# 562          tena      EC  -0.9833  -77.8167        62  No hotel found
# 565       wyndham      US  37.6985  -77.6125        52  No hotel found
# 575       iquique      CL -20.2208  -70.1431        68  No hotel found
#
# [166 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_df.hvplot.points('Lng', 'Lat', geo=True, alpha=0.4, size = "Humidity",
                       xlim=(-180, 180), ylim=(-70, 85), tiles=tile,legend='right',color = "City", 
                       hover_cols = ["Hotel Name","Country"])

# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
